# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
x = torch.rand((3, 3)).to(device)

print("Tensor:")
print(x)
print("Device Used:", device)
# Out:
# Tensor:
# tensor([[0.1459, 0.5970, 0.1574],
#         [0.5694, 0.8571, 0.5172],
#         [0.7305, 0.4514, 0.3761]])
# Device Used: cpu
